# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *

df = spark.readStream.format("rate").option("rowsPerSecond",10).load()

path = 'dbfs:/Volumes/workspace/default/anas_dataset/test1'

# %%
#display(df,checkpointLocation = path)

# %%
df.writeStream.outputMode("append").option("checkpointLocation", "dbfs:/Volumes/workspace/default/anas_dataset/").trigger(availableNow=True).toTable("stream_table")
